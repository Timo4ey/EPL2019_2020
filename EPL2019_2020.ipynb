# %%
import pandas as pd
import kaggle
import zipfile
from glob import glob

# %% [markdown]
# ### Extract data from .ZIP

# %%
# file = zipfile.ZipFile(glob('*.zip')[0])
# file.extractall()

# %% [markdown]
# ### Open the file

# %%
filename = glob('*.xlsx')[0]
filename
# Out:
# 'premierLeague.xlsx'

# %%
soccer_df = pd.read_excel('premierLeague.xlsx')

# %%
soccer_df.describe()
# Out:
#             Score  Penalties       Fouls     Corners     Crosses      Touches  \
# count  760.000000      760.0  760.000000  760.000000  760.000000   760.000000
# mean     1.360526        0.0   12.601316    5.342105   12.064474   610.294737
# std      1.233703        0.0    4.052065    3.063030    5.676598   133.400227
# min      0.000000        0.0    2.000000    0.000000    0.000000   362.000000
# 25%      0.000000        0.0   10.000000    3.000000    8.000000   509.000000
# 50%      1.000000        0.0   12.000000    5.000000   11.000000   596.000000
# 75%      2.000000        0.0   15.000000    7.000000   16.000000   694.750000
# max      9.000000        0.0   27.000000   18.000000   40.000000  1081.000000
#
#           Tackles  Interceptions  Aerials Won  Clearances  ...  Possession  \
# count  760.000000     760.000000   760.000000  760.000000  ...  760.000000
# mean    17.698684       7.213158    18.436842   26.836842  ...    0.500039
# ...
